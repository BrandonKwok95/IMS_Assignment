# %%
import matplotlib.pyplot as plt
import numpy as np
# 创建一个点数为 8 x 6 的窗口, 并设置分辨率为 80像素/每英寸
def preset_figure(values,title,ylabel):
    plt.figure(figsize=(10, 10), dpi=100)
    N = 6
    width = 0.45
    p2 = plt.bar(index, values, width, label="num", color="#87CEFA")
    plt.xlabel('clusters')
    plt.ylabel(ylabel)
    plt.title(title)
    preset_set = ['slower','medium','fast','faster','superfast','ultrafast']
    plt.xticks(index, preset_set)
    plt.show()

# %%
preset_figure([567,426,242,345,343,434],'ddd','file size')
